# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('c:/datasets/winequality-red_cleanout.csv')

# %%
df.to_csv('c:/datasets/newfile.csv')

# %%
df
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 0              0            7.4             0.700         0.00
# 1              1            7.8             0.880         0.00
# 2              2            7.8             0.760         0.04
# 3              3           11.2             0.280         0.56
# 4              4            7.4             0.700         0.00
# ...          ...            ...               ...          ...
# 1037        1592            6.3             0.510         0.13
# 1038        1593            6.8             0.620         0.08
# 1039        1594            6.2             0.600         0.08
# 1040        1596            6.3             0.510         0.13
# 1041        1597            5.9             0.645         0.12
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
# Box and Whisker Plots
from matplotlib import pyplot
from pandas import read_csv
data = df 
data.plot(kind='box', subplots=True, layout=(3,5), sharex=False, sharey=False)
plt.gcf().set_size_inches(20,20)
pyplot.show()

# %%
Check for Duplicates

# %%
sample = df.loc[df['alcohol']==11.0]

# %%
sample
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 140          216            8.7             0.625         0.16
# 151          229            6.9             0.520         0.25
# 155          233            6.9             0.520         0.25
# 197          314            7.4             0.360         0.29
# 198          315            7.1             0.350         0.29
# 208          333            8.4             0.560         0.08
# 219          356           11.5             0.410         0.52
# 239          397           11.5             0.590         0.59
# 240          398           11.5             0.590         0.59
# 254          423           10.5             0.240         0.47
# 259          430           10.5             0.240         0.47
# 320          543           11.2             0.660         0.24
# 328          570           11.5             0.350         0.49
# 372          647            8.3             0.845         0.01
# ...

# %%
dupDF = pd.concat([df, sample])

# %%
dupDF
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 0              0            7.4             0.700         0.00
# 1              1            7.8             0.880         0.00
# 2              2            7.8             0.760         0.04
# 3              3           11.2             0.280         0.56
# 4              4            7.4             0.700         0.00
# ...          ...            ...               ...          ...
# 969         1503            6.2             0.440         0.39
# 1010        1554            6.6             0.855         0.02
# 1013        1557            6.6             0.855         0.02
# 1037        1592            6.3             0.510         0.13
# 1040        1596            6.3             0.510         0.13
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
pandas.DataFrame.duplicated(subset=None, keep= ‘first’)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1037    False
# 1038    False
# 1039    False
# 1040    False
# 1041    False
# Length: 1042, dtype: bool

# %%
list(df.duplicated())
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
df.duplicated().any()
# Out:
# False

# %%
dupList = list(df.duplicated())

cnt = 0
for row in dupList:
    if row == True:
        idx = dupList.index(row)
        print(f'duplicate row at row  {cnt}')
        cnt+=1
    else:
        print('no duplicates found')
# Out:
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# no duplicates found
# ...

# %%
dupList = list(dupDF.duplicated())

cnt = 0
for row in dupList:
    
    
    if row == True:
        idx = dupList.index(row)
        print(f'duplicate row at row  {cnt}')
        cnt+=1
    else:
        cnt+=1
# Out:
# duplicate row at row  1042
# duplicate row at row  1043
# duplicate row at row  1044
# duplicate row at row  1045
# duplicate row at row  1046
# duplicate row at row  1047
# duplicate row at row  1048
# duplicate row at row  1049
# duplicate row at row  1050
# duplicate row at row  1051
# duplicate row at row  1052
# duplicate row at row  1053
# duplicate row at row  1054
# duplicate row at row  1055
# duplicate row at row  1056
# duplicate row at row  1057
# duplicate row at row  1058
# duplicate row at row  1059
# duplicate row at row  1060
# duplicate row at row  1061
# duplicate row at row  1062
# duplicate row at row  1063
# duplicate row at row  1064
# duplicate row at row  1065
# duplicate row at row  1066
# duplicate row at row  1067
# duplicate row at row  1068
# duplicate row at row  1069
# duplicate row at row  1070
# duplicate row at row  1071
# duplicate row at row  1072
# duplicate row at row  1073
# duplicate row at row  1074
# duplicate row at row  1075
# ...

# %%
data_df = {'Name': ['Arpit', 'Riya', 'Priyanka', 'Aman', 'Arpit', 'Rohan', 'Riya', 'Sakshi'],

           'Employment Type': ['Full-time Employee', 'Part-time Employee', 'Intern', 'Intern',
                               'Full-time Employee', 'Part-time Employee', 'Part-time Employee', 'Full-time Employee'],

           'Department': ['Administration', 'Marketing', 'Technical', 'Marketing',
                          'Administration', 'Technical', 'Marketing', 'Administration']}

df = pd.DataFrame(data_df)
df
# Out:
#        Name     Employment Type      Department
# 0     Arpit  Full-time Employee  Administration
# 1      Riya  Part-time Employee       Marketing
# 2  Priyanka              Intern       Technical
# 3      Aman              Intern       Marketing
# 4     Arpit  Full-time Employee  Administration
# 5     Rohan  Part-time Employee       Technical
# 6      Riya  Part-time Employee       Marketing
# 7    Sakshi  Full-time Employee  Administration

# %%
bool_series = df.duplicated()
bool_series
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
Removing Duplicates


first
last
Default

# %%
df.duplicated(keep= 'first')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
df.duplicated(keep= 'last')
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
dupRecs = df.duplicated(keep= 'first')

df[~dupRecs]
# Out:
#        Name     Employment Type      Department
# 0     Arpit  Full-time Employee  Administration
# 1      Riya  Part-time Employee       Marketing
# 2  Priyanka              Intern       Technical
# 3      Aman              Intern       Marketing
# 5     Rohan  Part-time Employee       Technical
# 7    Sakshi  Full-time Employee  Administration

# %%
dupRecs1 = df.duplicated(keep= 'last')

dfx = df[~dupRecs1]

# %%
dfx
# Out:
#        Name     Employment Type      Department
# 2  Priyanka              Intern       Technical
# 3      Aman              Intern       Marketing
# 4     Arpit  Full-time Employee  Administration
# 5     Rohan  Part-time Employee       Technical
# 6      Riya  Part-time Employee       Marketing
# 7    Sakshi  Full-time Employee  Administration

# %%
Feature Selection

# %%
Factors that in

# %%
df
# Out:
#        Name     Employment Type      Department
# 0     Arpit  Full-time Employee  Administration
# 1      Riya  Part-time Employee       Marketing
# 2  Priyanka              Intern       Technical
# 3      Aman              Intern       Marketing
# 4     Arpit  Full-time Employee  Administration
# 5     Rohan  Part-time Employee       Technical
# 6      Riya  Part-time Employee       Marketing
# 7    Sakshi  Full-time Employee  Administration

# %%
df1
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 0              0            7.4             0.700         0.00
# 1              1            7.8             0.880         0.00
# 2              2            7.8             0.760         0.04
# 3              3           11.2             0.280         0.56
# 4              4            7.4             0.700         0.00
# ...          ...            ...               ...          ...
# 1037        1592            6.3             0.510         0.13
# 1038        1593            6.8             0.620         0.08
# 1039        1594            6.2             0.600         0.08
# 1040        1596            6.3             0.510         0.13
# 1041        1597            5.9             0.645         0.12
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
Univariate Feature Selection Method

# %%
# Feature Extraction with Univariate Statistical Tests (Chi-squared for classification)
from pandas import read_csv
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
x = df1[['fixed acidity', 'volatile acidity', 'citric acid',
       'residual sugar', 'chlorides', 'free sulfur dioxide',
       'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']]

y = df1['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1037            6.3             0.510         0.13             2.3      0.076
# 1038            6.8             0.620         0.08             1.9      0.068
# 1039            6.2             0.600         0.08             2.0      0.090
# 1040            6.3             0.510         0.13             2.3      0.076
# 1041            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1037    6
# 1038    6
# 1039    5
# 1040    6
# 1041    5
# Name: quality, Length: 1042, dtype: int64

# %%
# Convert a dataframe to an array

# %%
df1.values
# Out:
# array([[0.000e+00, 7.400e+00, 7.000e-01, ..., 5.600e-01, 9.400e+00,
#         5.000e+00],
#        [1.000e+00, 7.800e+00, 8.800e-01, ..., 6.800e-01, 9.800e+00,
#         5.000e+00],
#        [2.000e+00, 7.800e+00, 7.600e-01, ..., 6.500e-01, 9.800e+00,
#         5.000e+00],
#        ...,
#        [1.594e+03, 6.200e+00, 6.000e-01, ..., 5.800e-01, 1.050e+01,
#         5.000e+00],
#        [1.596e+03, 6.300e+00, 5.100e-01, ..., 7.500e-01, 1.100e+01,
#         6.000e+00],
#        [1.597e+03, 5.900e+00, 6.450e-01, ..., 7.100e-01, 1.020e+01,
#         5.000e+00]])

# %%
dfArr = df1.values

X = dfArr[0:1041,0:12]

# %%
dfArr = df1.values

dfArr = df1.values

X = dfArr[:,1:12]

# %%
X
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 6.2  ,  0.6  ,  0.08 , ...,  3.45 ,  0.58 , 10.5  ],
#        [ 6.3  ,  0.51 ,  0.13 , ...,  3.42 ,  0.75 , 11.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ]])

# %%
Y= dfArr[:,12]

# %%
Y
# Out:
# array([5., 5., 5., ..., 5., 6., 5.])

# %%
# Feature Extraction with Univariate Statistical Tests (Chi-squared for classification)
from pandas import read_csv
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2


dfArr = df1.values
X = dfArr[:,1:12]
Y = dfArr[:,12]

# feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=3)
print(fit.scores_)
features = fit.transform(X)

# run a wquick model to get accuracy score
# summarize selected features
print(features[0:10,:])
# Out:
# [3.683e+00 6.216e+00 7.231e+00 5.346e-03 9.417e-02 4.923e+01 7.441e+02
#  1.348e-04 3.419e-02 4.261e+00 2.556e+01]
# [[0.0e+00 1.1e+01 3.4e+01 9.4e+00]
#  [0.0e+00 2.5e+01 6.7e+01 9.8e+00]
#  [4.0e-02 1.5e+01 5.4e+01 9.8e+00]
#  [5.6e-01 1.7e+01 6.0e+01 9.8e+00]
#  [0.0e+00 1.1e+01 3.4e+01 9.4e+00]
#  [0.0e+00 1.3e+01 4.0e+01 9.4e+00]
#  [6.0e-02 1.5e+01 5.9e+01 9.4e+00]
#  [0.0e+00 1.5e+01 2.1e+01 1.0e+01]
#  [2.0e-02 9.0e+00 1.8e+01 9.5e+00]
#  [8.0e-02 1.5e+01 6.5e+01 9.2e+00]]

# %%
selectedFeatures = pd.DataFrame(features)

selectedFeatures
# Out:
#          0     1     2     3
# 0     0.00  11.0  34.0   9.4
# 1     0.00  25.0  67.0   9.8
# 2     0.04  15.0  54.0   9.8
# 3     0.56  17.0  60.0   9.8
# 4     0.00  11.0  34.0   9.4
# ...    ...   ...   ...   ...
# 1037  0.13  29.0  40.0  11.0
# 1038  0.08  28.0  38.0   9.5
# 1039  0.08  32.0  44.0  10.5
# 1040  0.13  29.0  40.0  11.0
# 1041  0.12  32.0  44.0  10.2
#
# [1042 rows x 4 columns]

# %%
subsetCols = ['citric acid','free sulfur dioxide','total sulfur dioxide', 'alcohol']

selectedFeatures.columns = subsetCols
selectedFeatures
# Out:
#       citric acid  free sulfur dioxide  total sulfur dioxide  alcohol
# 0            0.00                 11.0                  34.0      9.4
# 1            0.00                 25.0                  67.0      9.8
# 2            0.04                 15.0                  54.0      9.8
# 3            0.56                 17.0                  60.0      9.8
# 4            0.00                 11.0                  34.0      9.4
# ...           ...                  ...                   ...      ...
# 1037         0.13                 29.0                  40.0     11.0
# 1038         0.08                 28.0                  38.0      9.5
# 1039         0.08                 32.0                  44.0     10.5
# 1040         0.13                 29.0                  40.0     11.0
# 1041         0.12                 32.0                  44.0     10.2
#
# [1042 rows x 4 columns]

# %%
# Feature Extraction with RFE
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

dfArr = df1.values
X = dfArr[:,1:12]
Y = dfArr[:,12]
# feature extraction
model = LogisticRegression(max_iter = 5000 )
#model = GaussianNB()
rfe = RFE(model,n_features_to_select=4)
fit = rfe.fit(X, Y)
print("Num Features: {}".format(fit.n_features_)) 
print("Selected Features: {}".format(fit.support_))
print("Feature Ranking: {}".format(fit.ranking_))
# Out:
# Num Features: 4
# Selected Features: [False  True False False False False False False  True  True  True]
# Feature Ranking: [5 1 2 3 4 6 8 7 1 1 1]

# %%
subsetCols1 = ['volatile acidity', 'pH', 'sulphates', 'alcohol']

rfeSelectedDF = df1[subsetCols1]
rfeSelectedDF
# Out:
#       volatile acidity    pH  sulphates  alcohol
# 0                0.700  3.51       0.56      9.4
# 1                0.880  3.20       0.68      9.8
# 2                0.760  3.26       0.65      9.8
# 3                0.280  3.16       0.58      9.8
# 4                0.700  3.51       0.56      9.4
# ...                ...   ...        ...      ...
# 1037             0.510  3.42       0.75     11.0
# 1038             0.620  3.42       0.82      9.5
# 1039             0.600  3.45       0.58     10.5
# 1040             0.510  3.42       0.75     11.0
# 1041             0.645  3.57       0.71     10.2
#
# [1042 rows x 4 columns]

# %%
df_univar = selectedFeatures

df_rfe = rfeSelectedDF

# %%
#Univariate Model 
from sklearn.model_selection import train_test_split

X = df_univar.values
Y =  dfArr[:,12]

test_size = 0.30
seed = 7
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size,random_state=seed)
model = LogisticRegression()
model.fit(X_train, Y_train)
result = model.score(X_test, Y_test)
print("Accuracy: {}".format(result*100.0))
# Out:
# Accuracy: 55.59105431309904
# C:\Users\stanl\anaconda3b\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#RFE
from sklearn.model_selection import train_test_split

X = df_rfe.values
Y =  dfArr[:,12]

test_size = 0.30
seed = 7
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size,random_state=seed)
model = LogisticRegression()
model.fit(X_train, Y_train)
result = model.score(X_test, Y_test)
print("Accuracy: {}".format(result*100.0))
# Out:
# Accuracy: 60.063897763578275
# C:\Users\stanl\anaconda3b\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Y
# Out:
# array([5., 5., 5., ..., 5., 6., 5.])

# %%
Principal Component Analysis

# %%
Principal Component Analysis (or PCA) uses linear algebra to transform the dataset into a
compressed form. 

Generally this is called a data reduction technique. 
A property of PCA is that you can choose the number of dimensions or principal components 
in the transformed result. 
In the example below, we use PCA and select 3 principal components.

# %%
# Feature Extraction with PCA
from pandas import read_csv
from sklearn.decomposition import PCA
# load data
#filename = 'c:/dataset/master/pima-indians-diabetes.data.csv'
#names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
#dataframe = read_csv(filename, names=names)

array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
pca = PCA(n_components=3)
fit = pca.fit(X)
# summarize components
print("Explained Variance: {}".format(fit.explained_variance_ratio_))
print(fit.components_)

# %%
Feature Importance

# %%
Bagged decision trees like Random Forest and Extra Trees 
can be used to estimate the importance of features. 

In the example below we construct a ExtraTreesClassifier classiffier for the Pima
Indians onset of diabetes dataset.

# %%
# Feature Importance with Extra Trees Classifier
from pandas import read_csv
from sklearn.ensemble import ExtraTreesClassifier
# load data
'''filename = 'c:/dataset/master/pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)'''

array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
model = ExtraTreesClassifier(3)
model.fit(X, Y)
print(model.feature_importances_)

# %%
You can see that we are given an importance score for each attribute where the larger the
score, the more important the attribute. 
The scores suggest the importance of plas, age and mass.
[ 0.11070069 0.2213717'
